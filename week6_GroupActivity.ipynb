# %%
import pandas as pd
data=pd.read_csv("Dataset_w6.csv")
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %% [markdown]
# # 1. Find out how many countries are there in the dataset

# %%
data['country'].count()
# Out:
# 196

# %% [markdown]
# There are 196 countries in dataset

# %% [markdown]
# # 2. Examine the data by using visualizations

# %%
#code by Daina maria
import matplotlib.pyplot as plt
import seaborn as sns
gdp=data[['country',"GDP per capita (current US$)"]]
top10=gdp.sort_values("GDP per capita (current US$)",ascending=False).head(10)
print(top10)
plt.figure(figsize=(12,8))
sns.barplot(x="country",y="GDP per capita (current US$)",data=top10)
plt.title("Top 10 countries based on GDP")
# Out:
#                       country  GDP per capita (current US$)
# 104                Luxembourg                      100160.8
# 18                    Bermuda                       94399.9
# 169               Switzerland                       80831.1
# 38           China, Macao SAR                       78586.4
# 130                    Norway                       74185.5
# 141                     Qatar                       73653.4
# 33             Cayman Islands                       62132.0
# 86                    Ireland                       60513.6
# 187  United States of America                       56053.8
# 51                    Denmark                       53149.3
# Text(0.5, 1.0, 'Top 10 countries based on GDP')

# %%
# code by Daina maria
pop=data[['country',"Population in thousands (2017)"]]
top10=pop.sort_values("Population in thousands (2017)",ascending=False).head(10)
print(top10)
plt.figure(figsize=(12,8))
sns.barplot(x="country",y="Population in thousands (2017)",data=top10)
plt.title("Top 10 countries based on Population in thousands (2017)")
# Out:
#                       country  Population in thousands (2017)
# 39                      China                         1409517
# 82                      India                         1339180
# 187  United States of America                          324460
# 83                  Indonesia                          263991
# 23                     Brazil                          209288
# 132                  Pakistan                          197016
# 129                   Nigeria                          190886
# 12                 Bangladesh                          164670
# 145        Russian Federation                          143990
# 114                    Mexico                          129163
# Text(0.5, 1.0, 'Top 10 countries based on Population in thousands (2017)')

# %% [markdown]
# # 3. Find out how many countries with respect to the region are available in the dataset

# %%
#code by gokul v u
data.groupby('Region')['country'].count().reset_index()
# Out:
#                Region  country
# 0           Caribbean       16
# 1      CentralAmerica        8
# 2         CentralAsia        5
# 3       EasternAfrica       17
# 4         EasternAsia        7
# 5       EasternEurope       10
# 6           Melanesia        5
# 7          Micronesia        4
# 8        MiddleAfrica        9
# 9      NorthernAfrica        5
# 10    NorthernAmerica        4
# 11     NorthernEurope       10
# 12            Oceania        2
# 13          Polynesia        5
# 14  South-easternAsia       11
# 15       SouthAmerica       12
# 16     SouthernAfrica        5
# 17       SouthernAsia        9
# 18     SouthernEurope       12
# 19      WesternAfrica       15
# 20        WesternAsia       18
# 21      WesternEurope        7

# %% [markdown]
# # 4. On average which region has the highest
# ## a. GDP per capita (current US)
# ##  b. International trade: Imports (million US$)

# %%
#code by shilpa grace v
import numpy as np
#based on GDP
data.groupby("Region")["GDP per capita (current US$)"].mean().sort_values(ascending=False)
# Out:
# Region
# NorthernAmerica      57659.000000
# WesternEurope        55387.128571
# Oceania              44823.250000
# NorthernEurope       42098.220000
# EasternAsia          27967.614286
# WesternAsia          17013.938889
# Caribbean            15135.562500
# SouthernEurope       14462.741667
# South-easternAsia    10299.027273
# EasternEurope         9292.490000
# Melanesia             9261.960000
# Polynesia             8686.520000
# SouthAmerica          8499.775000
# CentralAmerica        6348.137500
# Micronesia            5008.300000
# CentralAsia           4329.880000
# SouthernAfrica        4191.900000
# NorthernAfrica        3934.960000
# MiddleAfrica          3928.833333
# SouthernAsia          2968.400000
# EasternAfrica         2088.852941
# WesternAfrica         1013.140000
# Name: GDP per capita (current US$), dtype: float64

# %% [markdown]
# NorthernAmerica has highest  GDP per capita (current US)

# %%
import numpy as np
#based on International trade: Imports (million US$)
data.groupby("Region")["International trade: Imports (million US$)"].mean().sort_values(ascending=False)
# Out:
# Region
# NorthernAmerica      663552.250000
# EasternAsia          451995.000000
# WesternEurope        407498.428571
# NorthernEurope       113407.200000
# Oceania              112914.500000
# South-easternAsia     98324.636364
# EasternEurope         85243.900000
# SouthernEurope        76666.666667
# SouthernAsia          58199.333333
# CentralAmerica        57031.500000
# WesternAsia           46025.555556
# NorthernAfrica        35034.400000
# SouthAmerica          32885.666667
# SouthernAfrica        18005.600000
# CentralAsia           12063.400000
# WesternAfrica          4898.333333
# EasternAfrica          4726.176471
# MiddleAfrica           4381.222222
# Caribbean              3057.312500
# Melanesia              2896.400000
# Polynesia               432.000000
# Micronesia               99.000000
# Name: International trade: Imports (million US$), dtype: float64

# %% [markdown]
# NorthernAmerica has highest International trade: Imports (million US$)

# %% [markdown]
# # 5. Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
#code by Wafaha k p
data1=data[['GDP per capita (current US$)','Region']].groupby("Region").std().sort_values(by=['GDP per capita (current US$)'],inplace=False)
data1
# Out:
#                    GDP per capita (current US$)
# Region
# WesternAfrica                        815.095399
# NorthernAfrica                       974.706575
# SouthernAfrica                      2177.551120
# SouthernAsia                        2855.708179
# EasternAfrica                       3716.131770
# CentralAsia                         4152.215490
# CentralAmerica                      4180.440883
# SouthAmerica                        4273.707394
# Micronesia                          4820.669694
# MiddleAfrica                        5274.846281
# EasternEurope                       5415.488739
# Polynesia                           6956.250286
# Oceania                             9233.329638
# SouthernEurope                      9541.703216
# Melanesia                          13855.842686
# Caribbean                          14579.371326
# South-easternAsia                  16311.810656
# WesternAsia                        18812.151459
# ...

# %% [markdown]
# WesternAfrica is more consistent with respect to GDP per capita (current US$)

# %%
D1=data.groupby("Region")["GDP per capita (current US$)"]
D2=D1.describe()
D2
# Out:
#                    count          mean           std      min        25%  \
# Region
# Caribbean           16.0  15135.562500  14579.371326    793.7   6973.125
# CentralAmerica       8.0   6348.137500   4180.440883   2086.9   3558.100
# CentralAsia          5.0   4329.880000   4152.215490    925.9   1106.400
# EasternAfrica       17.0   2088.852941   3716.131770    144.5    529.200
# EasternAsia          7.0  27967.614286  27485.120923    648.0   6041.250
# EasternEurope       10.0   9292.490000   5415.488739   1591.4   6024.800
# Melanesia            5.0   9261.960000  13855.842686   1841.6   2783.000
# Micronesia           4.0   5008.300000   4820.669694   1442.9   2622.125
# MiddleAfrica         9.0   3928.833333   5274.846281    333.2    713.000
# NorthernAfrica       5.0   3934.960000    974.706575   2919.3   3452.300
# NorthernAmerica      4.0  57659.000000  25749.619445  36976.7  41648.375
# NorthernEurope      10.0  42098.220000  20671.030185  13704.1  23371.025
# ...

# %%
#Finding coefficient of variation
D3=D2['std']/D2['mean']*100
D3.sort_values()
# Out:
# Region
# Oceania               20.599420
# NorthernAfrica        24.770432
# NorthernAmerica       44.658457
# WesternEurope         44.722426
# NorthernEurope        49.101910
# SouthAmerica          50.280241
# SouthernAfrica        51.946638
# EasternEurope         58.278123
# CentralAmerica        65.853030
# SouthernEurope        65.974374
# Polynesia             80.080979
# WesternAfrica         80.452395
# CentralAsia           95.896780
# SouthernAsia          96.203617
# Micronesia            96.253613
# Caribbean             96.325269
# EasternAsia           98.274814
# WesternAsia          110.569055
# MiddleAfrica         134.259864
# Melanesia            149.599466
# South-easternAsia    158.382051
# EasternAfrica        177.902987
# dtype: float64

# %% [markdown]
# Oceania have the lowest coefficient of variation therefor the most consistent
